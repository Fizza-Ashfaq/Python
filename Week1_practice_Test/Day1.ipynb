# %%
##1.  Personal INformation

name=input("Enter name: ").title()
age=int(input("Enter your age: "))
city=input("Enter your city: ").title()
language=input("Enter your favourite promgramming language: ").title()

print(f"{name} aged {age} living in {city}, loves {language} programming language")

# %%
##2. Basic Calculator

num1=int(input("Enter number 1:"))
num2=int(input("Enter number 2:"))
op=input("Enter operation you want to perform(+,-,*,/):")

if op=="+":
    print(f"Addition: {num1+num2}")
elif op=="-":
    print(f"Subtraction: {num1-num2}")
elif op=="*":
    print(f"Multiplication: {num1*num2}")
elif op=="/":
    print(f"Division: {num1/num2}")
else:
    print("Invalid operation")

# %%
##3. Introduction Generator

name=input("Enter name: ").title()
age=int(input("Enter your age: "))
country=input("Enter your country: ").title()
profession=input("Enter your profession: ").title()

print(f"Hello, My name is {name}.")
print(f"I am {age} years old.")
print(f"I work as a {profession}.")
print(f"I am from {country}.")

# %%
##4. Age Calculator

year=int(input("Enter your birth year: "))
age=0

while year<2026:
    year=year+1
    age+=1
print(f"Your age is {age}")
# Out:
# Your age is 23

# %%
##5. Input Formatting Challenge

first_name=(input("Enter your first name: ").strip(" ")).title()
last_name=(input("Enter your last name: ").strip(" ")).title()
print(f"Full Name: {first_name} {last_name}")
# Out:
# Full Name: FizzaAshfaq

# %%
##6. Personal Information CLI

name=input("Enter name: ").title()
age=int(input("Enter your age: "))
email=input("Enter your email: ")
city=input("Enter your city: ").title()
exp=input("Enter your programming experience in years: ").title()
if (name==" " or age==" " or email==" " or city==" " or exp==" "):
    print("Please enter all the fields!")
else:
    print(f"Name: {name}")
    print(f"Age: {age}")
    print(f"Email: {email}")
    print(f"city: {city}")
    print(f"Profession: {exp}")
# Out:
# Name: Fizza
# Age: 67
# Email:
# city:
# Profession: Kh
