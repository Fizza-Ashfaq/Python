# %%
num1=int(input("Enter 1st number: "))
num2=int(input("Enter 2nd number: "))

print(f"Sum of both numbers: {num1+num2}")

# %%
principal_amount=int(input("Enter the principal amount: "))
time=int(input("Enter time period in years: "))
interest=int(input("Enter rate of interest: "))

total_interest=(principal_amount*time*interest)/100

print(f"Totral interest is : {total_interest}")

# %%
digit=int(input("Enter a digit: "))
l=len(str(digit))
sum_of_num=sum(int(d)**l for d in str(digit))

if (sum_of_num==digit):
    print("it's a Armstrong number")
else:
    print("Not an Armstrong number")

# %%
## Check Prime Number

num=int(input("Enter a number: "))
is_prime=False

if num>=2:
    for i in range(2,num):
        if num%i==0:
           is_prime=False
        else:
            is_prime=True

if(is_prime==False):
    print(f"{num} is not a prime number")
else:
    print(f"{num} is a prime number")

# %%
num=input("Enter a number: ")
print(f"ASCII value = {ord(num)}")
