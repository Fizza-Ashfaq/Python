# %%
txt=input("Enter something: ")
txt=(txt.capitalize()).replace(" ","_")
print(txt)

# %%
email = "fizza.ashfaq@gmail.com"
print(email[0:12])

# %%
import os
filename=input("Enter filename with extension")
extension=os.path.splitext(filename)[1]
print(extension)

# %%
txt = "Good night Sam!"

x = "mSa"
y = "eJo"
z = "odnght"
txt2=str.maketrans(x, y, z)
print(txt.translate(txt2))
