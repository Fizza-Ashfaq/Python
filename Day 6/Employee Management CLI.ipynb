# %%
employees = []

def add_employee():
    employee={}
    employee["id"]=len(employees)+1
    employee["name"]=input("Enter name: ")
    employee["dep"]=input("Enter department:")
    employee["salary"]=input("Enter salary: ")
    employees.append(employee)
    print("Employee added successfuly")


def view_employees():
    print("---Employees---")
    for employee in employees:
        print(f"Id: {employee["id"]}")
        print(f"Name: {employee["name"]}")
        print(f"Department: {employee["dep"]}")
        print(f"Salary: {employee["salary"]}")

def search_employee():
    to_search=int(input("Enter employee id to search: "))
    for employee in employees:
        if to_search==employee["id"]:
            print("Enployee found: ")
            print(f"Id: {employee["id"]}")
            print(f"Name: {employee["name"]}")
            print(f"Department: {employee["dep"]}")
            print(f"Salary: {employee["salary"]}")
        

def update_employee():
    to_update=int(input("Enter employee id to update: "))
    for employee in employees:
        if to_update==employee["id"]:
            attribute=input("What do u want to update: ")
            employee[attribute]=input(f"Enter {attribute}")
            print("Employee updated successfuly!")

def delete_employee():
    to_delete=int(input("Enter employee id to delete: "))
    # print(employees[to_delete])
    for employee in employees:
        if to_delete==employee["id"]:
            employees.remove(employee)
            print("Employee deleted successfuly!")
    # if to_delete in employees:
    #     print(employees[to_delete])
    #     employees[to_delete].pop()
    #     print("Employee deleted successfuly!")

while True:
    print("\n--- Employee Management System ---")
    print("1. Add Employee")
    print("2. View Employees")
    print("3. Search Employee")
    print("4. Update Employee")
    print("5. Delete Employee")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_employee()
    elif choice == "2":
        view_employees()
    elif choice == "3":
        search_employee()
    elif choice == "4":
        update_employee()
    elif choice == "5":
        delete_employee()
    elif choice == "6":
        print("Exiting...")
        break
    else:
        print("Invalid choice.")
# Out:
# --- Employee Management System ---
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Employee
# 5. Delete Employee
# 6. Exit
# Employee added successfuly
#
# --- Employee Management System ---
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Employee
# 5. Delete Employee
# 6. Exit
# Employee deleted successfuly!
#
# --- Employee Management System ---
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Employee
# 5. Delete Employee
# 6. Exit
# ---Employees---
#
# --- Employee Management System ---
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Employee
# 5. Delete Employee
# 6. Exit
# Employee added successfuly
#
# --- Employee Management System ---
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Employee
# 5. Delete Employee
# 6. Exit
# Employee added successfuly
#
# --- Employee Management System ---
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# ...
